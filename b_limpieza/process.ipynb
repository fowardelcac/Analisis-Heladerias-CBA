# %%
import pandas as pd
from a_script import clean_maps

# %%
path_base = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\barilatte\reviews\maps.csv"
path_barilatte = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\barilatte\reviews\maps.csv"
path_casserrato = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\casseratto\reviews\maps.csv"
path_chuii = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\chuii\reviews\maps.csv" 
path_cremolatti = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\cremolatti\reviews\maps.csv" 
path_delbent = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\delbent\reviews\del_bent.csv" 
path_dipale = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\dipale\reviews\DiPale.csv"
path_famiglia = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\famiglia\reviews\maps.csv"  
path_gatelin = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\gatelin\reviews\Gatelin.csv" 
path_leroma = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\leroma\reviews\maps.csv"
path_lucciano = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\Luccianos\reviews\maps.csv"
path_melano = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\melano\reviews\Melano.csv"
path_rapanui = r"C:\Users\juans\Documents\Data Science\Heladerias\a_extraccion\rapanui\reviews\Rapanui.csv" 

df_list = []
brand_list = ["Barilatte", "Casseratto", "Chuii", "Cremolatti", "Del Bent", "Di Pale", "Famiglia", "Gatelin", "Leroma", "Lucciano's", "Melano", "Rapanui"]
path_list = [path_barilatte, path_casserrato, path_chuii, path_cremolatti, path_delbent, path_dipale, path_famiglia, path_gatelin, path_leroma, path_lucciano, path_melano, path_rapanui]

for i in range(12):
    df = pd.read_csv(path_list[i])
    df["Marca"] = brand_list[i]
    df_list.append(df)

# %%
df = pd.concat(df_list, axis=0)
df
# Out:
#                  Usuario       Rating            Fecha  \
# 0               Lucas RC  4 estrellas     Hace 3 meses
# 1           Paola Cabral  4 estrellas      Hace un año
# 2                 Mica G  4 estrellas  3 semanas atrás
# 3      Victor Altamirano  5 estrellas  3 semanas atrás
# 4    María Dolores Ñáñez  5 estrellas      Hace 5 días
# ..                   ...          ...              ...
# 355    José María Correa  5 estrellas     Hace 7 meses
# 356     Fernando Decuzzi  5 estrellas     Hace 7 meses
# 357           Fran villu  5 estrellas     Hace 7 meses
# 358  Rodrigo Basconcello  5 estrellas     Hace 8 meses
# 359       Diego Chertoff  4 estrellas     Hace 8 meses
#
#                                            Descripcion  \
# 0    Son un 10 los helados y la atención.\nAdemás e...
# 1    Local nuevo en alta cordoba, los helados se de...
# 2    Helado muy rico, ame el macaron. Faltaba como ...
# 3    Los mejores helados de Córdoba, junto con la a...
# ...

# %%
data = df.copy()
data_cleaned = clean_maps(data)

# %%
data_cleaned.head()
# Out:
#                Usuario  Rating       Fecha  \
# 0             Lucas RC       4  11/12/2024
# 1         Paola Cabral       4  11/03/2024
# 2               Mica G       4  18/02/2025
# 3    Victor Altamirano       5  18/02/2025
# 4  María Dolores Ñáñez       5  06/03/2025
#
#                                          Descripcion                Local  \
# 0  Son un 10 los helados y la atención.\nAdemás e...  Emilio Lamarca 3683
# 1  Local nuevo en alta cordoba, los helados se de...  Emilio Lamarca 3683
# 2  Helado muy rico, ame el macaron. Faltaba como ...  Emilio Lamarca 3683
# 3  Los mejores helados de Córdoba, junto con la a...  Emilio Lamarca 3683
# 4  Muy buena atención siempre, helados de  buena ...  Emilio Lamarca 3683
#
#        Marca                              Descripcion_Procesada  \
# 0  Barilatte  son un  los helados y la atención además el lu...
# 1  Barilatte  local nuevo en alta cordoba los helados se des...
# ...

# %%
data_cleaned.to_csv("Cleaned_data.csv", index=False)
